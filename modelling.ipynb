# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
students_performance = pd.read_csv('StudentsPerformance.csv')

# %%
students_performance.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
reading_score = students_performance.get('reading_score')
math_score = students_performance.get('math_score')
writing_score = students_performance.get('writing_score')
race_etnicity = students_performance.get('race_etnicity')

#to get the columns

# %%
plt.scatter(reading_score, math_score, c=students_performance['gender'].map({'female': 'red', 'male':'blue'}))
plt.xlabel('reading score')
plt.ylabel('math score')
plt.show()

# %%
import scipy.stats as stats

# %%
stats.pearsonr(reading_score, math_score)
# Out:
# PearsonRResult(statistic=0.8175796636720539, pvalue=1.7877531099061487e-241)

# %%
plt.scatter(reading_score, writing_score, c=students_performance['gender'].map({'female':'red', 'male' : 'blue'}))
plt.xlabel('reading score')
plt.ylabel('writing score')
plt.title('reading and writing score')
plt.show()

# %%
stats.pearsonr(reading_score, writing_score)
# Out:
# PearsonRResult(statistic=0.9545980771462479, pvalue=0.0)

# %%
import seaborn as sn

# %%
import statsmodels.formula.api as sm

# %%
model1 = sm.ols(formula='Income ~ Age', data = Age_Income).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 model1 = sm.ols(formula='Income ~ Age', data = Age_Income).fit()
#
# NameError: name 'Age_Income' is not defined
